# %%
from sklearn.datasets import make_moons   
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# crating dummy nonliner data
X_moons, y_moons = make_moons(n_samples=1000, noise=0.08, random_state=78)

# %%
#transforming y_moons to a vertical vector
y_moons = y_moons.reshape(-1,1)

# %%
# creat a dataframe to plot the nonlinear dummy data
df_moons = pd.DataFrame(X_moons, columns=['Feature 1', 'Feature 2'])
df_moons['Target'] = y_moons
df_moons.head()
# Out:
#    Feature 1  Feature 2  Target
# 0   0.676217   0.815220       0
# 1   1.487143  -0.210519       1
# 2  -1.027709   0.354966       0
# 3   0.236012   1.025531       0
# 4   1.856695  -0.042783       1

# %%
# plot the nonlinear dummy data
df_moons.plot.scatter(x='Feature 1', y='Feature 2', c='Target', colormap='winter')

# %%
# Create training and testing sets
X_moon_train, X_moon_test, y_moon_train, y_moon_test = train_test_split(
    X_moons, y_moons, random_state=78
)

# %%
# Create the scaler instance
X_moon_scaler = skl.preprocessing.StandardScaler()

# %%
# Fit the scaler
X_moon_scaler.fit(X_moon_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
# Scale the data
X_moon_train_scaled = X_moon_scaler.transform(X_moon_train)
X_moon_test_scaled = X_moon_scaler.transform(X_moon_test)

# %%
# Training the model with the nonlinear data
model_moon = nn_model.fit(X_moon_train_scaled, y_moon_train, epochs=100, shuffle=True)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 2/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 3/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 4/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 5/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 6/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 7/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 8/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 9/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 10/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 11/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 12/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 13/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 14/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 15/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 16/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 17/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 18/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 19/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 20/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 21/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 22/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 23/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 24/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 25/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 26/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 27/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 28/100
# 24/24 [==============================] - 0s 2ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 29/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 30/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 31/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 32/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 33/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 34/100
# 24/24 [==============================] - 0s 991us/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 35/100
# 24/24 [==============================] - 0s 2ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 36/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 37/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 38/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 39/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 40/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 41/100
# 24/24 [==============================] - 0s 2ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 42/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 43/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 44/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 45/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 46/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 47/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 48/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 49/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 50/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 51/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 52/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 53/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 54/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 55/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 56/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 57/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 58/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 59/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 60/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 61/100
# 24/24 [==============================] - 0s 2ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 62/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 63/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 64/100
# 24/24 [==============================] - 0s 2ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 65/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 66/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 67/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 68/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 69/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 70/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 71/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 72/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 73/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 74/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 75/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 76/100
# 24/24 [==============================] - 0s 2ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 77/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 78/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 79/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 80/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 81/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 82/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 83/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 84/100
# 24/24 [==============================] - 0s 2ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 85/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 86/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 87/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 88/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 89/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 90/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 91/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 92/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 93/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 94/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 95/100
# 24/24 [==============================] - 0s 2ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 96/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 97/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 98/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 99/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413
# Epoch 100/100
# 24/24 [==============================] - 0s 1ms/step - loss: 6.2284 - accuracy: 0.1413

# %%
# create a data frame containing training history
history_df = pd.DataFrame(model_moon.history, index=range(1,len(model_moon.history['loss'])+1))
# Plot the loss
history_df.plot(y='loss')

# %%
# Plot the accuracy
history_df.plot(y="accuracy")
